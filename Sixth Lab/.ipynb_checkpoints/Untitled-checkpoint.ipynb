# %%
import numpy as np
import matplotlib.pyplot as plt
from itertools import product
import io
import sys
import pandas as pd

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/ahmad/.local/lib/python3.10/site-packages (2.1.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy<2,>=1.22.4 in /home/ahmad/.local/lib/python3.10/site-packages (from pandas) (1.26.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/ahmad/.local/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ahmad/.local/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
from Perceptron import Perceptron

# %%
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([0, 0, 0, 1])

# %%
def train(X, y, test_data, test_labels, input_size=2, learning_rate=0.01, epochs=10):
    perceptron = Perceptron(input_size=input_size, learning_rate=learning_rate, epochs=epochs)
    # Train the perceptron on the dataset
    perceptron.trainSGD(X, y)
    true_predict = 0
    for i, data in enumerate(test_data):
        prediction = perceptron.predict(data)
        if prediction == test_labels[i]:
            true_predict += 1
        print(f"Input: {data}, Prediction: {prediction}")
    return true_predict / len(test_labels)

# %%
epochs = [10, 20, 100, 200]
learning_rate = 0.01  
accuracy_epochs = []

# Suppress print statements
original_stdout = sys.stdout
sys.stdout = io.StringIO()

for epoch in epochs:
    accuracy = train(X, y, X, y, input_size=2, learning_rate=learning_rate, epochs=epoch)
    accuracy_epochs.append(accuracy)

# Restore print functionality
sys.stdout = original_stdout

# Plotting the results for varying epochs
plt.plot(epochs, accuracy_epochs, marker='o')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. Epochs with Learning Rate = 0.1')
plt.grid(True)
plt.show()

# %%
learning_rates = [0.01, 0.05, 0.1, 0.3]
epochs = 10
accuracy_learning = []

sys.stdout = io.StringIO()

for lr in learning_rates:
    accuracy = train(X, y, X, y, input_size=2, learning_rate=lr, epochs=epochs)
    accuracy_learning.append(accuracy)

sys.stdout = original_stdout

plt.plot(learning_rates, accuracy_learning, marker='o')
plt.xlabel('Learning Rate')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. Learning Rate with Epochs = 100')
plt.grid(True)
plt.show()

# %%
# %load_ext autoreload
# %autoreload 2

from Perceptron import Perceptron
sys.stdout = io.StringIO()

np.random.seed(42) # For reproducibility
num_samples = 100
x = np.random.uniform(low=0, high=10, size=num_samples)
z = 3 * x + 2
# Create a DataFrame to store the data
data = pd.DataFrame({'x': x, 'z': z})
# Extract the values of all columns (variables x and y) except the last one fromDataFrame
F = data.iloc[:, :-1].values
# Extract the values of the last column (output z) from DataFrame
O = data.iloc[:, -1].values
# Create a perceptron instance with appropriate input size
input_size = 1
perceptron = Perceptron(input_size=input_size, learning_rate=0.001, epochs=10)
# Train the perceptron on the dataset
perceptron.trainSGD_linear(F, O)
# Test the trained model
sys.stdout = original_stdout

for data in x:
    prediction = perceptron.predict_linear(data)
    print(f"Input: {data}, Actual: {3*data+2}, Prediction: {prediction}")
# Out:
# Input: 3.745401188473625, Actual: 13.236203565420874, Prediction: [12.95598945]
# Input: 9.50714306409916, Actual: 30.521429192297482, Prediction: [30.84827587]
# Input: 7.319939418114051, Actual: 23.959818254342153, Prediction: [24.05621977]
# Input: 5.986584841970366, Actual: 19.959754525911098, Prediction: [19.91567295]
# Input: 1.5601864044243652, Actual: 6.680559213273096, Prediction: [6.17010947]
# Input: 1.5599452033620265, Actual: 6.679835610086079, Prediction: [6.16936046]
# Input: 0.5808361216819946, Actual: 3.7425083650459836, Prediction: [3.12887366]
# Input: 8.661761457749352, Actual: 27.985284373248057, Prediction: [28.22306111]
# Input: 6.011150117432088, Actual: 20.033450352296263, Prediction: [19.99195699]
# Input: 7.080725777960454, Actual: 23.242177333881365, Prediction: [23.31337514]
# Input: 0.20584494295802447, Actual: 2.6175348288740734, Prediction: [1.96439081]
# Input: 9.699098521619943, Actual: 31.097295564859827, Prediction: [31.4443668]
# Input: 8.324426408004218, Actual: 26.973279224012654, Prediction: [27.17551412]
# Input: 2.1233911067827616, Actual: 8.370173320348284, Prediction: [7.91906319]
# Input: 1.0789142699330445, Actual: 5.236742809799134, Prediction: [4.67558593]

# %%
def linear_perceptron(F, O, input_size=1, learning_rate=0.001, epochs=10):
    perceptron = Perceptron(input_size=input_size, learning_rate=0.001, epochs=10)
    perceptron.trainSGD_linear(F, O)

    actual_values = O
    predictions = [perceptron.predict_linear(data_point) for data_point in x]

    mse = np.mean((actual_values - predictions) ** 2)
    print(f"Mean Squared Error (MSE): {mse}")

    ss_res = np.sum((actual_values - predictions) ** 2)

    mean_actual = np.mean(actual_values)
    ss_tot = np.sum((actual_values - mean_actual) ** 2)
    
    r_squared = 1 - (ss_res / ss_tot)
    print(f"Coefficient of Determination (R^2): {r_squared}")
    return mse, r_squared, perceptron

# %%
def draw(F, O):
    sys.stdout = io.StringIO()
    epoch = [i for i in range(1, 100)]
    mses = []
    for i in epoch:
        mse, _,  perceptron = linear_perceptron(F, O, epochs=epoch)
        mses.append(mse)
    sys.stdout = original_stdout
    plt.plot(epoch, mses)
    plt.xlabel('Number of Epochs')
    plt.ylabel('Mean Squared Error (MSE)')
    plt.title('MSE vs. Number of Epochs')
    plt.show()

    plt.plot(F, O)
    plt.plot(F, [perceptron.predict_linear(data_point) for data_point in F], label='Approximated Function')
    plt.title('Actual vs. Approximated Function')
    plt.legend()
    plt.show()

# %%
draw(F, O)

# %%
def draw(F, O):
    # Suppress print statements
    original_stdout = sys.stdout
    sys.stdout = io.StringIO()

    epochs = [i for i in range(1, 100)]
    mses = []
    for epoch in epochs:
        mse, _, perceptron = linear_perceptron(F, O, input_size=2, epochs=epoch)
        mses.append(mse)

    # Restore print functionality
    sys.stdout = original_stdout

    # Plotting MSE vs. Number of Epochs
    plt.plot(epochs, mses)
    plt.xlabel('Number of Epochs')
    plt.ylabel('Mean Squared Error (MSE)')
    plt.title('MSE vs. Number of Epochs')
    plt.show()

    # Plotting Actual vs. Approximated Function
    # Assuming the last trained perceptron is used
    approximated_values = [perceptron.predict_linear(data_point) for data_point in F]

    # 3D plot for x, y, and O
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(F[:, 0], F[:, 1], O, label='Actual Function')
    ax.scatter(F[:, 0], F[:, 1], approximated_values, label='Approximated Function', color='r')
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Output')
    plt.title('Actual vs. Approximated Function')
    plt.legend()
    plt.show()

# %%
x = np.random.uniform(low=0, high=10, size=num_samples)
y = np.random.uniform(low=0, high=10, size=num_samples)

z = 2 * x + 3 * y
# Create a DataFrame to store the data
data = pd.DataFrame({'x': x, 'y': y, 'z': z})
# Extract the values of all columns (variables x and y) except the last one fromDataFrame
F = data.iloc[:, :-1].values
# Extract the values of the last column (output z) from DataFrame
O = data.iloc[:, -1].values

# %%
draw(F, O)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 draw(F, O)
#
# Cell In[31], line 9, in draw(F, O)
#       7 mses = []
#       8 for epoch in epochs:
# ----> 9     mse, _, perceptron = linear_perceptron(F, O, input_size=2, epochs=epoch)
#      10     mses.append(mse)
#      12 # Restore print functionality
#
# Cell In[9], line 8, in linear_perceptron(F, O, input_size, learning_rate, epochs)
#       5 actual_values = O
#       6 predictions = [perceptron.predict_linear(data_point) for data_point in x]
# ----> 8 mse = np.mean((actual_values - predictions) ** 2)
#       9 print(f"Mean Squared Error (MSE): {mse}")
#      11 ss_res = np.sum((actual_values - predictions) ** 2)
#
# ValueError: operands could not be broadcast together with shapes (100,) (100,2)

# %%
predictions.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 predictions.shape
#
# NameError: name 'predictions' is not defined
